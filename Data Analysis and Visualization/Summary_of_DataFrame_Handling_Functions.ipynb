# %%
# numerical calculation & data frames
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

# statistics
import statsmodels.api as sm

# pandas options
pd.set_option('mode.copy_on_write', True)  # pandas 2.0
pd.options.display.float_format = '{:.2f}'.format  # pd.reset_option('display.float_format')
pd.options.display.max_rows = 7  # max number of rows to display

# NumPy options
np.set_printoptions(precision = 2, suppress=True)  # suppress scientific notation

# For high resolution display
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats("retina")

# %%
# import a dataset
diamonds = sm.datasets.get_rdataset("diamonds", "ggplot2").data
diamonds2 = diamonds.copy()  # unmodified copy

# %%
# Load the nycflight13 dataset
flights = sm.datasets.get_rdataset("flights", "nycflights13").data
flights["time_hour"] = pd.to_datetime(flights["time_hour"], utc=False).dt.tz_convert("America/New_York")  # convert to datetime
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1    517.00             515       2.00    830.00
# 1       2013      1    1    533.00             529       4.00    850.00
# 2       2013      1    1    542.00             540       2.00    923.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819      11.00      UA    1545  N14228    EWR  IAH
# 1                  830      20.00      UA    1714  N24211    LGA  IAH
# 2                  850      33.00      AA    1141  N619AA    JFK  MIA
# ...                ...        ...     ...     ...     ...    ...  ...
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute                 time_hour
# 0         227.00      1400     5      15 2013-01-01 05:00:00-05:00
# 1         227.00      1416     5      29 2013-01-01 05:00:00-05:00
# 2         160.00      1089     5      40 2013-01-01 05:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336773       NaN       764    12      10 2013-09-30 12:00:00-04:00
# 336774       NaN       419    11      59 2013-09-30 11:00:00-04:00
# 336775       NaN       431     8      40 2013-09-30 08:00:00-04:00
#
# [336776 rows x 19 columns]

# %%
airlines = sm.datasets.get_rdataset("airlines", "nycflights13").data

# %%
airports = sm.datasets.get_rdataset("airports", "nycflights13").data

# %%
planes = sm.datasets.get_rdataset("planes", "nycflights13").data

# %%
weather = sm.datasets.get_rdataset("weather", "nycflights13").data
weather["time_hour"] = pd.to_datetime(weather["time_hour"], utc=False).dt.tz_convert("America/New_York")  # convert to datetime

# %%
# tidy data
table1 = sm.datasets.get_rdataset("table1", "tidyr").data

# %%
table2 = sm.datasets.get_rdataset("table2", "tidyr").data

# %%
table3 = sm.datasets.get_rdataset("table3", "tidyr").data

# %%
table4a = sm.datasets.get_rdataset("table4a", "tidyr").data

# %%
table4b = sm.datasets.get_rdataset("table4b", "tidyr").data

# %% [markdown]
# # pd.Categorical: 카테고리의 순서 지정
# ## defualt: alphabetical order

# %%
pd.Categorical(diamonds["cut"])
# Out:
# ['Ideal', 'Premium', 'Good', 'Premium', 'Good', ..., 'Ideal', 'Good', 'Very Good', 'Premium', 'Ideal']
# Length: 53940
# Categories (5, object): ['Fair', 'Good', 'Ideal', 'Premium', 'Very Good']

# %%
diamonds2["cut"].astype("category")
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
#            ...
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Fair', 'Good', 'Ideal', 'Premium', 'Very Good']

# %%
# 제일 많이 씀
diamonds["cut"] = pd.Categorical(
    diamonds["cut"],
    categories=["Fair", "Good", "Very Good", "Premium", "Ideal"],
    ordered=True
)

# %%
# .astype() method를 쓰려면,
diamonds["cut"] = (
    diamonds["cut"]
    .astype("category")
    .cat.set_categories(["Fair", "Good", "Very Good", "Premium", "Ideal"], ordered=True)
)

# 또는
from pandas.api.types import CategoricalDtype

cat_type = CategoricalDtype(
    categories=["Fair", "Good", "Very Good", "Premium", "Ideal"], ordered=True
)
diamonds["cut2"] = diamonds["cut"].astype(cat_type)

# %%
diamonds["cut"]
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
#            ...
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
diamonds["cut"].cat.categories  # categories 확인
# Out:
# Index(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], dtype='object')

# %%
# 새로운 값인 perfect 추가하는 것도 가능
diamonds["cut2"] = pd.Categorical(
    diamonds["cut"],
    categories=["Fair", "Good", "Very Good", "Premium", "Ideal", "Perfect"],  # "Perfect" 추가
    ordered=True
)

# %%
diamonds.value_counts("cut2", sort=False)
# Out:
# cut2
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Perfect          0
# Name: count, dtype: int64

# %%
diamonds.value_counts("cut", sort=False)
# Out:
# cut
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: count, dtype: int64

# %%
# 결과의 index는 CategoricalIndex object
diamonds.value_counts("cut", sort=False).index
# Out:
# CategoricalIndex(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], categories=['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], ordered=True, dtype='category', name='cut')

# %%
# group keys
diamonds.groupby("cut2")["price"].mean()
# Out:
# cut2
# Fair        4358.76
# Good        3928.86
# Very Good   3981.76
# Premium     4584.26
# Ideal       3457.54
# Perfect         NaN
# Name: price, dtype: float64

# %%
# sort_values()에서도 카테고리 순서대로 정렬
diamonds.sort_values("cut")
# Out:
#        carat    cut color clarity  depth  table  price    x    y    z   cut2
# 4654    1.00   Fair     F     SI1  66.70  57.00   3669 6.07 5.99 4.02   Fair
# 53338   1.20   Fair     G      I1  64.40  55.00   2655 6.77 6.61 4.31   Fair
# 40890   0.50   Fair     E     SI1  65.00  58.00   1176 4.98 4.90 3.21   Fair
# ...      ...    ...   ...     ...    ...    ...    ...  ...  ...  ...    ...
# 29308   0.25  Ideal     G     VS1  62.70  54.00    438 4.05 4.08 2.55  Ideal
# 29339   0.31  Ideal     G     VS2  59.10  57.00    698 4.48 4.45 2.64  Ideal
# 53939   0.75  Ideal     D     SI2  62.20  55.00   2757 5.83 5.87 3.64  Ideal
#
# [53940 rows x 11 columns]

# %%
left = so.Plot(diamonds, x="cut2").add(so.Bar(), so.Count()).show()
right = so.Plot(diamonds2, x="cut").add(so.Bar(), so.Count()).show()  # catergorical type 아님

# %%
sns.boxplot(data=diamonds, x="cut2", y="price", fill=False)
# Out:
# <Axes: xlabel='cut2', ylabel='price'>

# %%
diamonds.boxplot("price", by="cut2")  # pandas boxplot
# Out:
# <Axes: title={'center': 'price'}, xlabel='cut2'>

# %% [markdown]
# # pd.cut, pd.qcut: 연속변수를 카테고리화하여 범주형 변수로 변환

# %%
# pd.cut: 동일한 길이의 10개 구간
(
    diamonds
    .assign(carrat_cut = lambda x:pd.cut(x.carat, 10))
    .value_counts("carrat_cut", sort = False)
)
# Out:
# carrat_cut
# (0.195, 0.681]    25155
# (0.681, 1.162]    18626
# (1.162, 1.643]     7129
#                   ...
# (3.567, 4.048]        5
# (4.048, 4.529]        2
# (4.529, 5.01]         1
# Name: count, Length: 10, dtype: int64

# %%
# 나누는 구간을 지정
(
    diamonds
    .assign(carat_cat = lambda x: pd.cut(x.carat, [0, 1, 3, 5]))
    .value_counts("carat_cat")
)
# Out:
# carat_cat
# (0, 1]    36438
# (1, 3]    17470
# (3, 5]       31
# Name: count, dtype: int64

# %%
# pd.qcut: 동일한 갯수의 관측치를 포함하도록 하는 10개의 구간; 구간의 길이가 모두 다름
(
    diamonds.assign(carat_cat = lambda x: pd.qcut(x.carat, 10))
    .value_counts("carat_cat", sort=False)
)
# Out:
# carat_cat
# (0.199, 0.31]    6452
# (0.31, 0.35]     4606
# (0.35, 0.42]     5421
#                  ...
# (1.01, 1.13]     4573
# (1.13, 1.51]     6052
# (1.51, 5.01]     4635
# Name: count, Length: 10, dtype: int64

# %%
(
    diamonds
    .assign(carat_cat = lambda x: pd.cut(x.carat, 10))
    .assign(carat_qcat = lambda x: pd.qcut(x.carat, 10))
)
# Out:
#        carat        cut color clarity  depth  table  price    x    y    z  \
# 0       0.23      Ideal     E     SI2  61.50  55.00    326 3.95 3.98 2.43
# 1       0.21    Premium     E     SI1  59.80  61.00    326 3.89 3.84 2.31
# 2       0.23       Good     E     VS1  56.90  65.00    327 4.05 4.07 2.31
# ...      ...        ...   ...     ...    ...    ...    ...  ...  ...  ...
# 53937   0.70  Very Good     D     SI1  62.80  60.00   2757 5.66 5.68 3.56
# 53938   0.86    Premium     H     SI2  61.00  58.00   2757 6.15 6.12 3.74
# 53939   0.75      Ideal     D     SI2  62.20  55.00   2757 5.83 5.87 3.64
#
#             cut2       carat_cat     carat_qcat
# 0          Ideal  (0.195, 0.681]  (0.199, 0.31]
# 1        Premium  (0.195, 0.681]  (0.199, 0.31]
# 2           Good  (0.195, 0.681]  (0.199, 0.31]
# ...          ...             ...            ...
# 53937  Very Good  (0.681, 1.162]    (0.53, 0.7]
# 53938    Premium  (0.681, 1.162]     (0.7, 0.9]
# 53939      Ideal  (0.681, 1.162]     (0.7, 0.9]
#
# [53940 rows x 13 columns]

# %% [markdown]
# # np.where: 조건에 해당하는 걸 찾거나, 변경하기

# %%
diamonds2 = diamonds.copy()
idx = diamonds['carat'] < 0.25
idx
# Out:
# 0         True
# 1         True
# 2         True
#          ...
# 53937    False
# 53938    False
# 53939    False
# Name: carat, Length: 53940, dtype: bool

# %%
diamonds2["color"] = np.where(idx, "E", "H")
diamonds2
# Out:
#        carat        cut color clarity  depth  table  price    x    y    z  \
# 0       0.23      Ideal     E     SI2  61.50  55.00    326 3.95 3.98 2.43
# 1       0.21    Premium     E     SI1  59.80  61.00    326 3.89 3.84 2.31
# 2       0.23       Good     E     VS1  56.90  65.00    327 4.05 4.07 2.31
# ...      ...        ...   ...     ...    ...    ...    ...  ...  ...  ...
# 53937   0.70  Very Good     H     SI1  62.80  60.00   2757 5.66 5.68 3.56
# 53938   0.86    Premium     H     SI2  61.00  58.00   2757 6.15 6.12 3.74
# 53939   0.75      Ideal     H     SI2  62.20  55.00   2757 5.83 5.87 3.64
#
#             cut2
# 0          Ideal
# 1        Premium
# 2           Good
# ...          ...
# 53937  Very Good
# 53938    Premium
# 53939      Ideal
#
# [53940 rows x 11 columns]

# %%
 # str method: "I"로 시작하는지 여부 --> 나머진 X로 바꿈
np.where(diamonds2["cut2"].str.startswith("I"), "I", "X")
# Out:
# array(['I', 'X', 'X', ..., 'X', 'X', 'I'], dtype='<U1')

# %% [markdown]
# # query(): 조건에 부합하는 데이터 추출

# %%
flights.query('arr_delay > 120')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 119     2013      1    1    811.00             630     101.00   1047.00
# 151     2013      1    1    848.00            1835     853.00   1001.00
# 218     2013      1    1    957.00             733     144.00   1056.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336724  2013      9   30   2053.00            1815     158.00   2310.00
# 336757  2013      9   30   2159.00            1845     194.00   2344.00
# 336763  2013      9   30   2235.00            2001     154.00     59.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 119                830     137.00      MQ    4576  N531MQ    LGA  CLT
# 151               1950     851.00      MQ    3944  N942MQ    JFK  BWI
# 218                853     123.00      UA     856  N534UA    EWR  BOS
# ...                ...        ...     ...     ...     ...    ...  ...
# 336724            2054     136.00      EV    5292  N600QX    EWR  ATL
# 336757            2030     194.00      9E    3320  N906XJ    JFK  BUF
# 336763            2249     130.00      B6    1083  N804JB    JFK  MCO
#
#         air_time  distance  hour  minute                 time_hour
# 119       118.00       544     6      30 2013-01-01 06:00:00-05:00
# 151        41.00       184    18      35 2013-01-01 18:00:00-05:00
# 218        37.00       200     7      33 2013-01-01 07:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336724     91.00       746    18      15 2013-09-30 18:00:00-04:00
# 336757     50.00       301    18      45 2013-09-30 18:00:00-04:00
# 336763    123.00       944    20       1 2013-09-30 20:00:00-04:00
#
# [10034 rows x 19 columns]

# %%
flights.query('month == 1 and day == 1')
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0    2013      1    1    517.00             515       2.00    830.00
# 1    2013      1    1    533.00             529       4.00    850.00
# 2    2013      1    1    542.00             540       2.00    923.00
# ..    ...    ...  ...       ...             ...        ...       ...
# 839  2013      1    1       NaN            1935        NaN       NaN
# 840  2013      1    1       NaN            1500        NaN       NaN
# 841  2013      1    1       NaN             600        NaN       NaN
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0               819      11.00      UA    1545  N14228    EWR  IAH    227.00
# 1               830      20.00      UA    1714  N24211    LGA  IAH    227.00
# 2               850      33.00      AA    1141  N619AA    JFK  MIA    160.00
# ..              ...        ...     ...     ...     ...    ...  ...       ...
# 839            2240        NaN      AA     791  N3EHAA    LGA  DFW       NaN
# 840            1825        NaN      AA    1925  N3EVAA    LGA  MIA       NaN
# 841             901        NaN      B6     125  N618JB    JFK  FLL       NaN
#
#      distance  hour  minute                 time_hour
# 0        1400     5      15 2013-01-01 05:00:00-05:00
# 1        1416     5      29 2013-01-01 05:00:00-05:00
# 2        1089     5      40 2013-01-01 05:00:00-05:00
# ..        ...   ...     ...                       ...
# 839      1389    19      35 2013-01-01 19:00:00-05:00
# 840      1096    15       0 2013-01-01 15:00:00-05:00
# 841      1069     6       0 2013-01-01 06:00:00-05:00
#
# [842 rows x 19 columns]

# %%
flights.query('month in [1, 2]')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1    517.00             515       2.00    830.00
# 1       2013      1    1    533.00             529       4.00    850.00
# 2       2013      1    1    542.00             540       2.00    923.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 136244  2013      2   28       NaN            1115        NaN       NaN
# 136245  2013      2   28       NaN             830        NaN       NaN
# 136246  2013      2   28       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819      11.00      UA    1545  N14228    EWR  IAH
# 1                  830      20.00      UA    1714  N24211    LGA  IAH
# 2                  850      33.00      AA    1141  N619AA    JFK  MIA
# ...                ...        ...     ...     ...     ...    ...  ...
# 136244            1310        NaN      MQ    4485  N725MQ    LGA  CMH
# 136245            1205        NaN      UA    1480     NaN    EWR  SFO
# 136246            1147        NaN      UA     443     NaN    JFK  LAX
#
#         air_time  distance  hour  minute                 time_hour
# 0         227.00      1400     5      15 2013-01-01 05:00:00-05:00
# 1         227.00      1416     5      29 2013-01-01 05:00:00-05:00
# 2         160.00      1089     5      40 2013-01-01 05:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 136244       NaN       479    11      15 2013-02-28 11:00:00-05:00
# 136245       NaN      2565     8      30 2013-02-28 08:00:00-05:00
# 136246       NaN      2475     8      40 2013-02-28 08:00:00-05:00
#
# [51955 rows x 19 columns]

# %%
flights.query('arr_delay > 120 and not (origin == "JFK")')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 119     2013      1    1    811.00             630     101.00   1047.00
# 218     2013      1    1    957.00             733     144.00   1056.00
# 268     2013      1    1   1114.00             900     134.00   1447.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336529  2013      9   30   1738.00            1529     129.00   1906.00
# 336668  2013      9   30   1951.00            1649     182.00   2157.00
# 336724  2013      9   30   2053.00            1815     158.00   2310.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 119                830     137.00      MQ    4576  N531MQ    LGA  CLT
# 218                853     123.00      UA     856  N534UA    EWR  BOS
# 268               1222     145.00      UA    1086  N76502    LGA  IAH
# ...                ...        ...     ...     ...     ...    ...  ...
# 336529            1649     137.00      EV    4580  N12563    EWR  MKE
# 336668            1903     174.00      EV    4294  N13988    EWR  SAV
# 336724            2054     136.00      EV    5292  N600QX    EWR  ATL
#
#         air_time  distance  hour  minute                 time_hour
# 119       118.00       544     6      30 2013-01-01 06:00:00-05:00
# 218        37.00       200     7      33 2013-01-01 07:00:00-05:00
# 268       248.00      1416     9       0 2013-01-01 09:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336529    110.00       725    15      29 2013-09-30 15:00:00-04:00
# 336668     95.00       708    16      49 2013-09-30 16:00:00-04:00
# 336724     91.00       746    18      15 2013-09-30 18:00:00-04:00
#
# [6868 rows x 19 columns]

# %%
flights.query('dep_time < sched_dep_time')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 3       2013      1    1    544.00             545      -1.00   1004.00
# 4       2013      1    1    554.00             600      -6.00    812.00
# 5       2013      1    1    554.00             558      -4.00    740.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336766  2013      9   30   2240.00            2250     -10.00   2347.00
# 336767  2013      9   30   2241.00            2246      -5.00   2345.00
# 336769  2013      9   30   2349.00            2359     -10.00    325.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 3                 1022     -18.00      B6     725  N804JB    JFK  BQN
# 4                  837     -25.00      DL     461  N668DN    LGA  ATL
# 5                  728      12.00      UA    1696  N39463    EWR  ORD
# ...                ...        ...     ...     ...     ...    ...  ...
# 336766               7     -20.00      B6    2002  N281JB    JFK  BUF
# 336767               1     -16.00      B6     486  N346JB    JFK  ROC
# 336769             350     -25.00      B6     745  N516JB    JFK  PSE
#
#         air_time  distance  hour  minute                 time_hour
# 3         183.00      1576     5      45 2013-01-01 05:00:00-05:00
# 4         116.00       762     6       0 2013-01-01 06:00:00-05:00
# 5         150.00       719     5      58 2013-01-01 05:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336766     52.00       301    22      50 2013-09-30 22:00:00-04:00
# 336767     47.00       264    22      46 2013-09-30 22:00:00-04:00
# 336769    196.00      1617    23      59 2013-09-30 23:00:00-04:00
#
# [184782 rows x 19 columns]

# %%
flights.query('arr_delay + dep_delay < 0')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 3       2013      1    1    544.00             545      -1.00   1004.00
# 4       2013      1    1    554.00             600      -6.00    812.00
# 7       2013      1    1    557.00             600      -3.00    709.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336766  2013      9   30   2240.00            2250     -10.00   2347.00
# 336767  2013      9   30   2241.00            2246      -5.00   2345.00
# 336769  2013      9   30   2349.00            2359     -10.00    325.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 3                 1022     -18.00      B6     725  N804JB    JFK  BQN
# 4                  837     -25.00      DL     461  N668DN    LGA  ATL
# 7                  723     -14.00      EV    5708  N829AS    LGA  IAD
# ...                ...        ...     ...     ...     ...    ...  ...
# 336766               7     -20.00      B6    2002  N281JB    JFK  BUF
# 336767               1     -16.00      B6     486  N346JB    JFK  ROC
# 336769             350     -25.00      B6     745  N516JB    JFK  PSE
#
#         air_time  distance  hour  minute                 time_hour
# 3         183.00      1576     5      45 2013-01-01 05:00:00-05:00
# 4         116.00       762     6       0 2013-01-01 06:00:00-05:00
# 7          53.00       229     6       0 2013-01-01 06:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336766     52.00       301    22      50 2013-09-30 22:00:00-04:00
# 336767     47.00       264    22      46 2013-09-30 22:00:00-04:00
# 336769    196.00      1617    23      59 2013-09-30 23:00:00-04:00
#
# [188401 rows x 19 columns]

# %%
# dep_delay는 NaN 값이 아니고, arr_delay는 NaN 값인 경우
flights.query('not dep_delay.isna() and arr_delay.isna()')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 471     2013      1    1   1525.00            1530      -5.00   1934.00
# 477     2013      1    1   1528.00            1459      29.00   2002.00
# 615     2013      1    1   1740.00            1745      -5.00   2158.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 334495  2013      9   28   1214.00            1225     -11.00   1801.00
# 335534  2013      9   29   1734.00            1711      23.00   2159.00
# 335805  2013      9   30    559.00             600      -1.00       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 471               1805        NaN      MQ    4525  N719MQ    LGA  XNA
# 477               1647        NaN      EV    3806  N17108    EWR  STL
# 615               2020        NaN      MQ    4413  N739MQ    LGA  XNA
# ...                ...        ...     ...     ...     ...    ...  ...
# 334495            1510        NaN      AA     300  N488AA    EWR  DFW
# 335534            2020        NaN      UA     327  N463UA    EWR  PDX
# 335805             715        NaN      WN     464  N411WN    EWR  MDW
#
#         air_time  distance  hour  minute                 time_hour
# 471          NaN      1147    15      30 2013-01-01 15:00:00-05:00
# 477          NaN       872    14      59 2013-01-01 14:00:00-05:00
# 615          NaN      1147    17      45 2013-01-01 17:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 334495       NaN      1372    12      25 2013-09-28 12:00:00-04:00
# 335534       NaN      2434    17      11 2013-09-29 17:00:00-04:00
# 335805       NaN       711     6       0 2013-09-30 06:00:00-04:00
#
# [1175 rows x 19 columns]

# %%
# 외부 변수 참조
delay_cutoff = 120
flights.query('arr_delay > @delay_cutoff')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 119     2013      1    1    811.00             630     101.00   1047.00
# 151     2013      1    1    848.00            1835     853.00   1001.00
# 218     2013      1    1    957.00             733     144.00   1056.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336724  2013      9   30   2053.00            1815     158.00   2310.00
# 336757  2013      9   30   2159.00            1845     194.00   2344.00
# 336763  2013      9   30   2235.00            2001     154.00     59.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 119                830     137.00      MQ    4576  N531MQ    LGA  CLT
# 151               1950     851.00      MQ    3944  N942MQ    JFK  BWI
# 218                853     123.00      UA     856  N534UA    EWR  BOS
# ...                ...        ...     ...     ...     ...    ...  ...
# 336724            2054     136.00      EV    5292  N600QX    EWR  ATL
# 336757            2030     194.00      9E    3320  N906XJ    JFK  BUF
# 336763            2249     130.00      B6    1083  N804JB    JFK  MCO
#
#         air_time  distance  hour  minute                 time_hour
# 119       118.00       544     6      30 2013-01-01 06:00:00-05:00
# 151        41.00       184    18      35 2013-01-01 18:00:00-05:00
# 218        37.00       200     7      33 2013-01-01 07:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336724     91.00       746    18      15 2013-09-30 18:00:00-04:00
# 336757     50.00       301    18      45 2013-09-30 18:00:00-04:00
# 336763    123.00       944    20       1 2013-09-30 20:00:00-04:00
#
# [10034 rows x 19 columns]

# %%
# 외부 함수 참조
def cut_off(df):
    return df["dep_delay"].min()

flights.query('arr_delay < @cut_off(@flights)')
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 694     2013      1    1   1859.00            1900      -1.00   2151.00
# 696     2013      1    1   1904.00            1905      -1.00   2139.00
# 860     2013      1    2    559.00             601      -2.00    809.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336634  2013      9   30   1913.00            1919      -6.00   2149.00
# 336638  2013      9   30   1918.00            1925      -7.00   2152.00
# 336722  2013      9   30   2052.00            2054      -2.00   2306.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 694               2238     -47.00      DL    1967  N329NW    JFK  MIA
# 696               2227     -48.00      DL    2159  N3758Y    JFK  MCO
# 860                901     -52.00      UA     402  N484UA    EWR  LAS
# ...                ...        ...     ...     ...     ...    ...  ...
# 336634            2234     -45.00      B6      71  N615JB    JFK  SLC
# 336638            2248     -56.00      DL     498  N378NW    JFK  SAT
# 336722            2358     -52.00      B6    1295  N588JB    JFK  AUS
#
#         air_time  distance  hour  minute                 time_hour
# 694       150.00      1089    19       0 2013-01-01 19:00:00-05:00
# 696       133.00       944    19       5 2013-01-01 19:00:00-05:00
# 860       289.00      2227     6       1 2013-01-02 06:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336634    254.00      1990    19      19 2013-09-30 19:00:00-04:00
# 336638    190.00      1587    19      25 2013-09-30 19:00:00-04:00
# 336722    175.00      1521    20      54 2013-09-30 20:00:00-04:00
#
# [3425 rows x 19 columns]

# %% [markdown]
# # sort_values(): 정렬
# ## default: ascending=True (오름차순)
# ## index 순서가 바뀌는데, 이를 reset하려면 .sort_values(ignore_index = True)

# %%
# "year", "month", "day", "dep_time" 순서대로 내림차순으로 정렬
flights.sort_values(by=["year", "month", "day", "dep_time"], ascending=False)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 111279  2013     12   31   2356.00            2359      -3.00    436.00
# 111278  2013     12   31   2355.00            2359      -4.00    430.00
# 111277  2013     12   31   2332.00            2245      47.00     58.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 839     2013      1    1       NaN            1935        NaN       NaN
# 840     2013      1    1       NaN            1500        NaN       NaN
# 841     2013      1    1       NaN             600        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 111279             445      -9.00      B6     745  N665JB    JFK  PSE
# 111278             440     -10.00      B6    1503  N509JB    JFK  SJU
# 111277               3      55.00      B6     486  N334JB    JFK  ROC
# ...                ...        ...     ...     ...     ...    ...  ...
# 839               2240        NaN      AA     791  N3EHAA    LGA  DFW
# 840               1825        NaN      AA    1925  N3EVAA    LGA  MIA
# 841                901        NaN      B6     125  N618JB    JFK  FLL
#
#         air_time  distance  hour  minute                 time_hour
# 111279    200.00      1617    23      59 2013-12-31 23:00:00-05:00
# 111278    195.00      1598    23      59 2013-12-31 23:00:00-05:00
# 111277     60.00       264    22      45 2013-12-31 22:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 839          NaN      1389    19      35 2013-01-01 19:00:00-05:00
# 840          NaN      1096    15       0 2013-01-01 15:00:00-05:00
# 841          NaN      1069     6       0 2013-01-01 06:00:00-05:00
#
# [336776 rows x 19 columns]

# %%
flights.sort_values(by=["year", "month", "day", "dep_time"])
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1    517.00             515       2.00    830.00
# 1       2013      1    1    533.00             529       4.00    850.00
# 2       2013      1    1    542.00             540       2.00    923.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 111293  2013     12   31       NaN            1615        NaN       NaN
# 111294  2013     12   31       NaN             600        NaN       NaN
# 111295  2013     12   31       NaN             830        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819      11.00      UA    1545  N14228    EWR  IAH
# 1                  830      20.00      UA    1714  N24211    LGA  IAH
# 2                  850      33.00      AA    1141  N619AA    JFK  MIA
# ...                ...        ...     ...     ...     ...    ...  ...
# 111293            1800        NaN      MQ    3301  N844MQ    LGA  RDU
# 111294             735        NaN      UA     219     NaN    EWR  ORD
# 111295            1154        NaN      UA     443     NaN    JFK  LAX
#
#         air_time  distance  hour  minute                 time_hour
# 0         227.00      1400     5      15 2013-01-01 05:00:00-05:00
# 1         227.00      1416     5      29 2013-01-01 05:00:00-05:00
# 2         160.00      1089     5      40 2013-01-01 05:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 111293       NaN       431    16      15 2013-12-31 16:00:00-05:00
# 111294       NaN       719     6       0 2013-12-31 06:00:00-05:00
# 111295       NaN      2475     8      30 2013-12-31 08:00:00-05:00
#
# [336776 rows x 19 columns]

# %%
# "dep_time"은 내림차순으로, "arr_delay"는 오름차순으로
flights.sort_values(by=["dep_time", "arr_delay"], ascending=[False, True])
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 150301  2013      3   15   2400.00            2359       1.00    324.00
# 87893   2013     12    5   2400.00            2359       1.00    427.00
# 212941  2013      5   21   2400.00            2359       1.00    339.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 150301             338     -14.00      B6     727  N636JB    JFK  BQN
# 87893              440     -13.00      B6    1503  N587JB    JFK  SJU
# 212941             350     -11.00      B6     739  N527JB    JFK  PSE
# ...                ...        ...     ...     ...     ...    ...  ...
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute                 time_hour
# 150301    186.00      1576    23      59 2013-03-15 23:00:00-04:00
# 87893     182.00      1598    23      59 2013-12-05 23:00:00-05:00
# 212941    199.00      1617    23      59 2013-05-21 23:00:00-04:00
# ...          ...       ...   ...     ...                       ...
# 336773       NaN       764    12      10 2013-09-30 12:00:00-04:00
# 336774       NaN       419    11      59 2013-09-30 11:00:00-04:00
# 336775       NaN       431     8      40 2013-09-30 08:00:00-04:00
#
# [336776 rows x 19 columns]

# %%
(
    flights
    .query('dep_delay <= 10 and dep_delay >= -10')
    .sort_values('arr_delay', ascending=False)
)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 55985   2013     11    1    658.00             700      -2.00   1329.00
# 181270  2013      4   18    558.00             600      -2.00   1149.00
# 256340  2013      7    7   1659.00            1700      -1.00   2050.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 334354  2013      9   28    847.00             839       8.00   1130.00
# 334412  2013      9   28   1010.00            1020     -10.00   1344.00
# 335805  2013      9   30    559.00             600      -1.00       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 55985             1015     194.00      VX     399  N629VA    JFK  LAX
# 181270             850     179.00      AA     707  N3EXAA    LGA  DFW
# 256340            1823     147.00      US    2183  N948UW    LGA  DCA
# ...                ...        ...     ...     ...     ...    ...  ...
# 334354             959        NaN      EV    4510  N14542    EWR  MKE
# 334412            1222        NaN      EV    4412  N12175    EWR  DSM
# 335805             715        NaN      WN     464  N411WN    EWR  MDW
#
#         air_time  distance  hour  minute                 time_hour
# 55985     336.00      2475     7       0 2013-11-01 07:00:00-04:00
# 181270    234.00      1389     6       0 2013-04-18 06:00:00-04:00
# 256340     64.00       214    17       0 2013-07-07 17:00:00-04:00
# ...          ...       ...   ...     ...                       ...
# 334354       NaN       725     8      39 2013-09-28 08:00:00-04:00
# 334412       NaN      1017    10      20 2013-09-28 10:00:00-04:00
# 335805       NaN       711     6       0 2013-09-30 06:00:00-04:00
#
# [239109 rows x 19 columns]

# %% [markdown]
# # nlargest(): 값이 높은 것들 정렬 후 추출
# ## keep = "all" -- 중복값 모두 출력
# ## keep = "first" -- 중복된 값 중에서 첫 번째로 나타나는 값을 선택
# ## keep = "last" -- 중복된 값 중에서 마지막으로 나타나는 값을 선택

# %%
# 순서로 정렬
flights.nlargest(3, columns=["year", "month", "day", "dep_time"], keep="all")
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 111279  2013     12   31   2356.00            2359      -3.00    436.00
# 111278  2013     12   31   2355.00            2359      -4.00    430.00
# 111277  2013     12   31   2332.00            2245      47.00     58.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 111279             445      -9.00      B6     745  N665JB    JFK  PSE
# 111278             440     -10.00      B6    1503  N509JB    JFK  SJU
# 111277               3      55.00      B6     486  N334JB    JFK  ROC
#
#         air_time  distance  hour  minute                 time_hour
# 111279    200.00      1617    23      59 2013-12-31 23:00:00-05:00
# 111278    195.00      1598    23      59 2013-12-31 23:00:00-05:00
# 111277     60.00       264    22      45 2013-12-31 22:00:00-05:00

# %% [markdown]
# # unique(): 유일한 값 찾기
# ## + nunique(): 유일한 값의 개수 찾기

# %%
flights["origin"].unique()
# Out:
# array(['EWR', 'LGA', 'JFK'], dtype=object)

# %%
flights["origin"].nunique()
# Out:
# 3

# %% [markdown]
# # value_counts(): 고유값의 개수 세주기
# ## default: dropna=True

# %%
flights[["origin", "dest"]].value_counts(sort=False) # Series
# Out:
# origin  dest
# EWR     ALB      439
#         ANC        8
#         ATL     5022
#                 ...
# LGA     TVC       77
#         TYS      308
#         XNA      745
# Name: count, Length: 224, dtype: int64

# %%
# reset_index로 데이터프레임 형식 만들고, values_count로 센 것을 n이라는 열로 저장
flights[["origin", "dest"]].value_counts(sort=False).reset_index(name="n")
# Out:
#     origin dest     n
# 0      EWR  ALB   439
# 1      EWR  ANC     8
# 2      EWR  ATL  5022
# ..     ...  ...   ...
# 221    LGA  TVC    77
# 222    LGA  TYS   308
# 223    LGA  XNA   745
#
# [224 rows x 3 columns]

# %% [markdown]
# # rename(): column이나 index 이름 바꾸기

# %%
flights.rename(
    columns = {'dep_time': "det_t", "arr_time": "arr_t"}
)
# Out:
#         year  month  day  det_t  sched_dep_time  dep_delay  arr_t  \
# 0       2013      1    1 517.00             515       2.00 830.00
# 1       2013      1    1 533.00             529       4.00 850.00
# 2       2013      1    1 542.00             540       2.00 923.00
# ...      ...    ...  ...    ...             ...        ...    ...
# 336773  2013      9   30    NaN            1210        NaN    NaN
# 336774  2013      9   30    NaN            1159        NaN    NaN
# 336775  2013      9   30    NaN             840        NaN    NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819      11.00      UA    1545  N14228    EWR  IAH
# 1                  830      20.00      UA    1714  N24211    LGA  IAH
# 2                  850      33.00      AA    1141  N619AA    JFK  MIA
# ...                ...        ...     ...     ...     ...    ...  ...
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute                 time_hour
# 0         227.00      1400     5      15 2013-01-01 05:00:00-05:00
# 1         227.00      1416     5      29 2013-01-01 05:00:00-05:00
# 2         160.00      1089     5      40 2013-01-01 05:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336773       NaN       764    12      10 2013-09-30 12:00:00-04:00
# 336774       NaN       419    11      59 2013-09-30 11:00:00-04:00
# 336775       NaN       431     8      40 2013-09-30 08:00:00-04:00
#
# [336776 rows x 19 columns]

# %%
# 인덱스 rename도 가능
flights.rename(
    index={0: "a", 1: "b"},
).head(3)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# a  2013      1    1    517.00             515       2.00    830.00
# b  2013      1    1    533.00             529       4.00    850.00
# 2  2013      1    1    542.00             540       2.00    923.00
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# a             819      11.00      UA    1545  N14228    EWR  IAH    227.00
# b             830      20.00      UA    1714  N24211    LGA  IAH    227.00
# 2             850      33.00      AA    1141  N619AA    JFK  MIA    160.00
#
#    distance  hour  minute                 time_hour
# a      1400     5      15 2013-01-01 05:00:00-05:00
# b      1416     5      29 2013-01-01 05:00:00-05:00
# 2      1089     5      40 2013-01-01 05:00:00-05:00

# %%
# 첫 문자 대문자로
flights.rename(str.capitalize, axis="columns").head(3)  # axis=1
# Out:
#    Year  Month  Day  Dep_time  Sched_dep_time  Dep_delay  Arr_time  \
# 0  2013      1    1    517.00             515       2.00    830.00
# 1  2013      1    1    533.00             529       4.00    850.00
# 2  2013      1    1    542.00             540       2.00    923.00
#
#    Sched_arr_time  Arr_delay Carrier  Flight Tailnum Origin Dest  Air_time  \
# 0             819      11.00      UA    1545  N14228    EWR  IAH    227.00
# 1             830      20.00      UA    1714  N24211    LGA  IAH    227.00
# 2             850      33.00      AA    1141  N619AA    JFK  MIA    160.00
#
#    Distance  Hour  Minute                 Time_hour
# 0      1400     5      15 2013-01-01 05:00:00-05:00
# 1      1416     5      29 2013-01-01 05:00:00-05:00
# 2      1089     5      40 2013-01-01 05:00:00-05:00

# %%
# 임의의 함수가 적용됨
flights.rename(lambda x: x[:3], axis="columns")
# Out:
#          yea  mon  day    dep   sch  dep    arr   sch   arr car   fli     tai  \
# 0       2013    1    1 517.00   515 2.00 830.00   819 11.00  UA  1545  N14228
# 1       2013    1    1 533.00   529 4.00 850.00   830 20.00  UA  1714  N24211
# 2       2013    1    1 542.00   540 2.00 923.00   850 33.00  AA  1141  N619AA
# ...      ...  ...  ...    ...   ...  ...    ...   ...   ...  ..   ...     ...
# 336773  2013    9   30    NaN  1210  NaN    NaN  1330   NaN  MQ  3461  N535MQ
# 336774  2013    9   30    NaN  1159  NaN    NaN  1344   NaN  MQ  3572  N511MQ
# 336775  2013    9   30    NaN   840  NaN    NaN  1020   NaN  MQ  3531  N839MQ
#
#         ori  des    air   dis  hou  min                       tim
# 0       EWR  IAH 227.00  1400    5   15 2013-01-01 05:00:00-05:00
# 1       LGA  IAH 227.00  1416    5   29 2013-01-01 05:00:00-05:00
# 2       JFK  MIA 160.00  1089    5   40 2013-01-01 05:00:00-05:00
# ...     ...  ...    ...   ...  ...  ...                       ...
# 336773  LGA  BNA    NaN   764   12   10 2013-09-30 12:00:00-04:00
# 336774  LGA  CLE    NaN   419   11   59 2013-09-30 11:00:00-04:00
# 336775  LGA  RDU    NaN   431    8   40 2013-09-30 08:00:00-04:00
#
# [336776 rows x 19 columns]

# %% [markdown]
# # assign(): 데이터프레임에 새로운 열(column)을 추가할 때 사용

# %%
cols = ["year", "month", "day", "distance", "air_time"] + \
        [col for col in flights.columns if col.endswith("delay")]  # string method .endswith
flights_sml = flights[cols].copy()
flights_sml
# Out:
#         year  month  day  distance  air_time  dep_delay  arr_delay
# 0       2013      1    1      1400    227.00       2.00      11.00
# 1       2013      1    1      1416    227.00       4.00      20.00
# 2       2013      1    1      1089    160.00       2.00      33.00
# ...      ...    ...  ...       ...       ...        ...        ...
# 336773  2013      9   30       764       NaN        NaN        NaN
# 336774  2013      9   30       419       NaN        NaN        NaN
# 336775  2013      9   30       431       NaN        NaN        NaN
#
# [336776 rows x 7 columns]

# %%
# 새로 만들어진 변수는 맨 뒤로
flights_sml.assign(
    gain=lambda x: x.dep_delay - x.arr_delay,   # x: DataFrame, flights_sml
    speed=lambda x: x.distance / x.air_time * 60
)
# Out:
#         year  month  day  distance  air_time  dep_delay  arr_delay   gain  \
# 0       2013      1    1      1400    227.00       2.00      11.00  -9.00
# 1       2013      1    1      1416    227.00       4.00      20.00 -16.00
# 2       2013      1    1      1089    160.00       2.00      33.00 -31.00
# ...      ...    ...  ...       ...       ...        ...        ...    ...
# 336773  2013      9   30       764       NaN        NaN        NaN    NaN
# 336774  2013      9   30       419       NaN        NaN        NaN    NaN
# 336775  2013      9   30       431       NaN        NaN        NaN    NaN
#
#         speed
# 0      370.04
# 1      374.27
# 2      408.38
# ...       ...
# 336773    NaN
# 336774    NaN
# 336775    NaN
#
# [336776 rows x 9 columns]

# %%
# 직접 DataFrame 참조할 수도 있음
flights_sml.assign(
gain=lambda x: flights_sml['dep_delay'] - flights_sml['arr_delay'],
    speed=flights_sml["distance"] / flights_sml["air_time"] * 60
)
# Out:
#         year  month  day  distance  air_time  dep_delay  arr_delay   gain  \
# 0       2013      1    1      1400    227.00       2.00      11.00  -9.00
# 1       2013      1    1      1416    227.00       4.00      20.00 -16.00
# 2       2013      1    1      1089    160.00       2.00      33.00 -31.00
# ...      ...    ...  ...       ...       ...        ...        ...    ...
# 336773  2013      9   30       764       NaN        NaN        NaN    NaN
# 336774  2013      9   30       419       NaN        NaN        NaN    NaN
# 336775  2013      9   30       431       NaN        NaN        NaN    NaN
#
#         speed
# 0      370.04
# 1      374.27
# 2      408.38
# ...       ...
# 336773    NaN
# 336774    NaN
# 336775    NaN
#
# [336776 rows x 9 columns]

# %%
# 앞에서 만든 변수나 함수를 이용할 수 있음
flights_sml.assign(
    gain=lambda x: x.dep_delay - x.arr_delay,
    hours=lambda x: x.air_time / 60,
    gain_per_hour=lambda x: x.gain / x.hours,
    rounded=lambda x: np.round(x.gain_per_hour, 1)  # use a numpy function
)
# Out:
#         year  month  day  distance  air_time  dep_delay  arr_delay   gain  \
# 0       2013      1    1      1400    227.00       2.00      11.00  -9.00
# 1       2013      1    1      1416    227.00       4.00      20.00 -16.00
# 2       2013      1    1      1089    160.00       2.00      33.00 -31.00
# ...      ...    ...  ...       ...       ...        ...        ...    ...
# 336773  2013      9   30       764       NaN        NaN        NaN    NaN
# 336774  2013      9   30       419       NaN        NaN        NaN    NaN
# 336775  2013      9   30       431       NaN        NaN        NaN    NaN
#
#         hours  gain_per_hour  rounded
# 0        3.78          -2.38    -2.40
# 1        3.78          -4.23    -4.20
# 2        2.67         -11.62   -11.60
# ...       ...            ...      ...
# 336773    NaN            NaN      NaN
# 336774    NaN            NaN      NaN
# 336775    NaN            NaN      NaN
#
# [336776 rows x 11 columns]

# %%
# Find the fastest flights
(
    flights_sml
    .assign(speed=lambda x: x.distance / x.air_time)
    .sort_values(by="speed", ascending=False)
    .head(5)
)
# Out:
#         year  month  day  distance  air_time  dep_delay  arr_delay  speed
# 216447  2013      5   25       762     65.00       9.00     -14.00  11.72
# 251999  2013      7    2      1008     93.00      45.00      26.00  10.84
# 205388  2013      5   13       594     55.00      15.00      -1.00  10.80
# 157516  2013      3   23       748     70.00       4.00       2.00  10.69
# 10223   2013      1   12      1035    105.00      -1.00     -28.00   9.86

# %% [markdown]
# # groupby(): 데이터를 그룹으로 나누어 분석할 수 있게 해줌
# ## .count(), .sum(), .mean(), .min(), .max()과 같은 통계치를 구하는 methods와 함께 자주 활용됨
# ## .size: group의 사이즈, 열의 개수, value_counts와 유사하게 쓰일 수 있음
# ## as_index=False: grouping 변수들을 index가 아닌 columns으로

# %%
flights.groupby("month")  # “GroupBy” object

# %%
flights_sml.groupby("month").mean()
# Out:
#          year   day  distance  air_time  dep_delay  arr_delay
# month
# 1     2013.00 15.99   1006.84    154.19      10.04       6.13
# 2     2013.00 14.74   1000.98    151.35      10.82       5.61
# 3     2013.00 16.00   1011.99    149.08      13.23       5.81
# ...       ...   ...       ...       ...        ...        ...
# 10    2013.00 15.98   1038.88    148.89       6.24      -0.17
# 11    2013.00 15.29   1050.31    155.47       5.44       0.46
# 12    2013.00 15.72   1064.66    162.59      16.58      14.87
#
# [12 rows x 6 columns]

# %%
# 보통은 다음과 같이 특정 columns을 선택
flights.groupby("month")["dep_delay"]  # [["dep_delay"]] 처럼 list로 입력하면 DataFrameGroupBy object

# %%
flights.groupby("month")["dep_delay"].mean()  # Series GroupBy object에 적용된 결과는 Series
# Out:
# month
# 1    10.04
# 2    10.82
# 3    13.23
#       ...
# 10    6.24
# 11    5.44
# 12   16.58
# Name: dep_delay, Length: 12, dtype: float64

# %%
flights.groupby("month")[["dep_delay", "arr_delay"]].mean().head(3)
# Out:
#        dep_delay  arr_delay
# month
# 1          10.04       6.13
# 2          10.82       5.61
# 3          13.23       5.81

# %%
# Multi-index의 level을 drop하려면 droplevel()
flights.groupby(["month", "day"])["arr_delay"].nsmallest(1).droplevel(2)
# Out:
# month  day
# 1      1     -48.00
#        2     -59.00
#        3     -65.00
#               ...
# 12     29    -60.00
#        30    -45.00
#        31    -44.00
# Name: arr_delay, Length: 365, dtype: float64

# %%
flights.groupby(["origin", "dest"])["arr_delay"].count()
# Out:
# origin  dest
# EWR     ALB      418
#         ANC        8
#         ATL     4876
#                 ...
# LGA     TVC       73
#         TYS      265
#         XNA      709
# Name: arr_delay, Length: 224, dtype: int64

# %%
flights.groupby(["month", "day"])["arr_delay"].mean()
# Out:
# month  day
# 1      1     12.65
#        2     12.69
#        3      5.73
#               ...
# 12     29    18.76
#        30    10.06
#        31     6.21
# Name: arr_delay, Length: 365, dtype: float64

# %%
flights.groupby(["month", "day"], as_index=False)["arr_delay"].mean().head(3)
# Out:
#    month  day  arr_delay
# 0      1    1      12.65
# 1      1    2      12.69
# 2      1    3       5.73

# %%
flights.groupby("dest").size()  # .size(): group의 사이즈/열의 갯수
# Out:
# dest
# ABQ     254
# ACK     265
# ALB     439
#        ...
# TVC     101
# TYS     631
# XNA    1036
# Length: 105, dtype: int64

# %%
flights.groupby("tailnum", dropna=False).size()  # groupby는 기본적으로 NA 무시
# Out:
# tailnum
# D942DN       4
# N0EGMQ     371
# N10156     153
#           ...
# N999DN      61
# N9EAMQ     248
# NaN       2512
# Length: 4044, dtype: int64

# %%
# 좀 더 복잡한 groupby filtering은 이후 apply를 이용
flights.groupby(["year", "month", "day"]).filter(lambda x: x["arr_delay"].mean() < 0)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 2699    2013      1    4     25.00            2359      26.00    505.00
# 2700    2013      1    4    106.00            2245     141.00    201.00
# 2701    2013      1    4    456.00             500      -4.00    631.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 2699               442      23.00      B6     707  N554JB    JFK  SJU
# 2700              2356     125.00      B6     608  N192JB    JFK  PWM
# 2701               650     -19.00      US    1030  N186US    EWR  CLT
# ...                ...        ...     ...     ...     ...    ...  ...
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute                 time_hour
# 2699      194.00      1598    23      59 2013-01-04 23:00:00-05:00
# 2700       44.00       273    22      45 2013-01-04 22:00:00-05:00
# 2701       77.00       529     5       0 2013-01-04 05:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336773       NaN       764    12      10 2013-09-30 12:00:00-04:00
# 336774       NaN       419    11      59 2013-09-30 11:00:00-04:00
# 336775       NaN       431     8      40 2013-09-30 08:00:00-04:00
#
# [137631 rows x 19 columns]

# %% [markdown]
# # agg(): 배열에서 스칼라 값을 생성하는 데이터 변환

# %%
# 모두 동일
flights_sml.groupby("month").mean()
flights_sml.groupby("month").agg("mean")  # function names
flights_sml.groupby("month").agg(np.mean)  # numpy functions
flights_sml.groupby("month").agg(lambda x: x.sum() / x.count())  # general functions; not optimized!
# Out:
#          year   day  distance  air_time  dep_delay  arr_delay
# month
# 1     2013.00 15.99   1006.84    154.19      10.04       6.13
# 2     2013.00 14.74   1000.98    151.35      10.82       5.61
# 3     2013.00 16.00   1011.99    149.08      13.23       5.81
# ...       ...   ...       ...       ...        ...        ...
# 10    2013.00 15.98   1038.88    148.89       6.24      -0.17
# 11    2013.00 15.29   1050.31    155.47       5.44       0.46
# 12    2013.00 15.72   1064.66    162.59      16.58      14.87
#
# [12 rows x 6 columns]

# %%
# Series에 string으로 함수 적용
flights_sml.groupby("month")["arr_delay"].agg("mean")
# Out:
# month
# 1     6.13
# 2     5.61
# 3     5.81
#       ...
# 10   -0.17
# 11    0.46
# 12   14.87
# Name: arr_delay, Length: 12, dtype: float64

# %%
# DataFrame에 적용해서 결과물: DataFrame
flights_sml.groupby("month")[["arr_delay"]].agg("mean")
# Out:
#        arr_delay
# month
# 1           6.13
# 2           5.61
# 3           5.81
# ...          ...
# 10         -0.17
# 11          0.46
# 12         14.87
#
# [12 rows x 1 columns]

# %%
flights.groupby("month")["dep_delay"].agg(["mean", "count"])
# Out:
#        mean  count
# month
# 1     10.04  26483
# 2     10.82  23690
# 3     13.23  27973
# ...     ...    ...
# 10     6.24  28653
# 11     5.44  27035
# 12    16.58  27110
#
# [12 rows x 2 columns]

# %%
# DataFrame Groupby object의 경우 column 별로 적용
flights_sml.groupby("month")[["arr_delay", "dep_delay"]].agg("mean")
# Out:
#        arr_delay  dep_delay
# month
# 1           6.13      10.04
# 2           5.61      10.82
# 3           5.81      13.23
# ...          ...        ...
# 10         -0.17       6.24
# 11          0.46       5.44
# 12         14.87      16.58
#
# [12 rows x 2 columns]

# %%
flights_sml.groupby("month")[["arr_delay", "dep_delay"]].agg(["mean", "count"])
# Out:
#       arr_delay        dep_delay
#            mean  count      mean  count
# month
# 1          6.13  26398     10.04  26483
# 2          5.61  23611     10.82  23690
# 3          5.81  27902     13.23  27973
# ...         ...    ...       ...    ...
# 10        -0.17  28618      6.24  28653
# 11         0.46  26971      5.44  27035
# 12        14.87  27020     16.58  27110
#
# [12 rows x 4 columns]

# %%
# 컬럼 별로 다른 함수를 적용하고자 할 때 (컬럼 이름을 지정)
flights_agg = (
    flights.groupby("month")
    .agg(
        air_min=("air_time", "min"),  # 컬럼 이름 지정 = (컬럼, 함수)
        air_max=("air_time", "max"),
        dep_mean=("dep_delay", "mean"),
        arr_median=("arr_delay", "median"),
    )
)

flights_agg
# Out:
#        air_min  air_max  dep_mean  arr_median
# month
# 1        20.00   667.00     10.04       -3.00
# 2        21.00   691.00     10.82       -3.00
# 3        21.00   695.00     13.23       -6.00
# ...        ...      ...       ...         ...
# 10       23.00   642.00      6.24       -7.00
# 11       24.00   676.00      5.44       -6.00
# 12       21.00   661.00     16.58        2.00
#
# [12 rows x 4 columns]

# %%
# 컬럼별 다른 함수를 적용하는 다른 방식: dictionary
flights_agg = flights.groupby("month").agg({
    "air_time": ["min", "max"],
    "dep_delay": "mean",
    "arr_delay": "median"
})

# %%
# MultiIndex를 collapse하는 팁

flights_agg.columns
# MultiIndex([( 'air_time',    'min'),
#             ( 'air_time',    'max'),
#             ('dep_delay',   'mean'),
#             ('arr_delay', 'median')],
#            )

flights_agg.columns = ['_'.join(col_agg) for col_agg in flights_agg.columns]
flights_agg.head(3)
# Out:
#        air_time_min  air_time_max  dep_delay_mean  arr_delay_median
# month
# 1             20.00        667.00           10.04             -3.00
# 2             21.00        691.00           10.82             -3.00
# 3             21.00        695.00           13.23             -6.00

# %%
# agg()에는 custom function을 pass할 수 있음
def peak_to_peak(arr):
    return arr.max() - arr.min()

grouped_dist = flights_sml.groupby(["month", "day"])["distance"]

grouped_dist.agg(["std", peak_to_peak])  # a list of functions
# Out:
#              std  peak_to_peak
# month day
# 1     1   727.73          4889
#       2   721.72          4889
#       3   714.95          4903
# ...          ...           ...
# 12    29  728.78          4887
#       30  723.88          4887
#       31  731.36          4887
#
# [365 rows x 2 columns]

# %%
# Naming a function as a tuple
grouped_dist.agg([("sd", "std"), ("range", peak_to_peak)])
# Out:
#               sd  range
# month day
# 1     1   727.73   4889
#       2   721.72   4889
#       3   714.95   4903
# ...          ...    ...
# 12    29  728.78   4887
#       30  723.88   4887
#       31  731.36   4887
#
# [365 rows x 2 columns]

# %% [markdown]
# # transform(): 함수는 그룹별 변환을 수행하거나 열별 변환을 수행할 때 사용
# ## 앞서 group별로 통계치가 summary되어 reduced 데이터프레임으로 변형됐다면, transform()은 group별로 얻은 통계치가 원래 데이터의 형태를 그대로 보존하면서 출력

# %%
# month로 reduce됨.
flights_sml.groupby(["month"])["arr_delay"].mean()
# Out:
# month
# 1     6.13
# 2     5.61
# 3     5.81
#       ...
# 10   -0.17
# 11    0.46
# 12   14.87
# Name: arr_delay, Length: 12, dtype: float64

# %%
grouped_delay = flights_sml.groupby(["month"])["arr_delay"].transform("mean")
grouped_delay
# Out:
# 0         6.13
# 1         6.13
# 2         6.13
#           ...
# 336773   -4.02
# 336774   -4.02
# 336775   -4.02
# Name: arr_delay, Length: 336776, dtype: float64

# %%
flights_sml["monthly_delay"] = grouped_delay
flights_sml
# Out:
#         year  month  day  distance  air_time  dep_delay  arr_delay  \
# 0       2013      1    1      1400    227.00       2.00      11.00
# 1       2013      1    1      1416    227.00       4.00      20.00
# 2       2013      1    1      1089    160.00       2.00      33.00
# ...      ...    ...  ...       ...       ...        ...        ...
# 336773  2013      9   30       764       NaN        NaN        NaN
# 336774  2013      9   30       419       NaN        NaN        NaN
# 336775  2013      9   30       431       NaN        NaN        NaN
#
#         monthly_delay
# 0                6.13
# 1                6.13
# 2                6.13
# ...               ...
# 336773          -4.02
# 336774          -4.02
# 336775          -4.02
#
# [336776 rows x 8 columns]

# %%
dest_size =  flights.groupby("dest").transform("size")
dest_size

# 또는 flights.groupby("dest")["dest"].transform("count")
# Out:
# 0          7198
# 1          7198
# 2         11728
#           ...
# 336773     6333
# 336774     4573
# 336775     8163
# Length: 336776, dtype: int64

# %%
# 1년에 10000편 이상 운항편이 있는 도착지에 대한 항공편
flights[dest_size >= 10000]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 2       2013      1    1    542.00             540       2.00    923.00
# 4       2013      1    1    554.00             600      -6.00    812.00
# 5       2013      1    1    554.00             558      -4.00    740.00
# ...      ...    ...  ...       ...             ...        ...       ...
# 336762  2013      9   30   2233.00            2113      80.00    112.00
# 336763  2013      9   30   2235.00            2001     154.00     59.00
# 336768  2013      9   30   2307.00            2255      12.00   2359.00
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 2                  850      33.00      AA    1141  N619AA    JFK  MIA
# 4                  837     -25.00      DL     461  N668DN    LGA  ATL
# 5                  728      12.00      UA    1696  N39463    EWR  ORD
# ...                ...        ...     ...     ...     ...    ...  ...
# 336762              30      42.00      UA     471  N578UA    EWR  SFO
# 336763            2249     130.00      B6    1083  N804JB    JFK  MCO
# 336768            2358       1.00      B6     718  N565JB    JFK  BOS
#
#         air_time  distance  hour  minute                 time_hour
# 2         160.00      1089     5      40 2013-01-01 05:00:00-05:00
# 4         116.00       762     6       0 2013-01-01 06:00:00-05:00
# 5         150.00       719     5      58 2013-01-01 05:00:00-05:00
# ...          ...       ...   ...     ...                       ...
# 336762    318.00      2565    21      13 2013-09-30 21:00:00-04:00
# 336763    123.00       944    20       1 2013-09-30 20:00:00-04:00
# 336768     33.00       187    22      55 2013-09-30 22:00:00-04:00
#
# [131440 rows x 19 columns]

# %%
# rank() 사용하여 하루 중 출발 지연이 가장 늦은 두 항공편들을 매일 각각 구하면,
def get_ranks(group):
    return group.rank(ascending=False, method="min")


delay_rank = flights.groupby(['month', 'day'])['dep_delay'].transform(get_ranks)
delay_rank
# Out:
# 0        302.00
# 1        269.00
# 2        302.00
#           ...
# 336773      NaN
# 336774      NaN
# 336775      NaN
# Name: dep_delay, Length: 336776, dtype: float64

# %%
flights[delay_rank < 3].head(6)
# Out:
#       year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 151   2013      1    1    848.00            1835     853.00   1001.00
# 834   2013      1    1   2343.00            1724     379.00    314.00
# 1440  2013      1    2   1607.00            1030     337.00   2003.00
# 1749  2013      1    2   2131.00            1512     379.00   2340.00
# 2598  2013      1    3   2008.00            1540     268.00   2339.00
# 2637  2013      1    3   2056.00            1605     291.00   2239.00
#
#       sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 151             1950     851.00      MQ    3944  N942MQ    JFK  BWI     41.00
# 834             1938     456.00      EV    4321  N21197    EWR  MCI    222.00
# 1440            1355     368.00      AA     179  N324AA    JFK  SFO    346.00
# 1749            1741     359.00      UA     488  N593UA    LGA  DEN    228.00
# 2598            1909     270.00      DL    2027  N338NW    JFK  FLL    158.00
# 2637            1754     285.00      9E    3459  N928XJ    JFK  BNA    125.00
#
#       distance  hour  minute                 time_hour
# 151        184    18      35 2013-01-01 18:00:00-05:00
# 834       1092    17      24 2013-01-01 17:00:00-05:00
# 1440      2586    10      30 2013-01-02 10:00:00-05:00
# 1749      1620    15      12 2013-01-02 15:00:00-05:00
# 2598      1069    15      40 2013-01-03 15:00:00-05:00
# 2637       765    16       5 2013-01-03 16:00:00-05:00

# %%
# air_time 변수 Normalize
dest_air = flights.groupby("dest")["air_time"]

def normalize(x):
    return (x - x.mean()) / x.std()

dest_air.transform(normalize)
# Out:
# 0        1.73
# 1        1.73
# 2        0.61
#          ...
# 336773    NaN
# 336774    NaN
# 336775    NaN
# Name: air_time, Length: 336776, dtype: float64

# %% [markdown]
# # apply():  함수는 사용자가 지정한 함수를 데이터프레임의 각 행 또는 열에 적용할 때 사용

# %%
tips = sns.load_dataset("tips")
tips = tips.assign(tip_pct = lambda x: x.tip / x.total_bill)
tips.head(3)
# Out:
#    total_bill  tip     sex smoker  day    time  size  tip_pct
# 0       16.99 1.01  Female     No  Sun  Dinner     2     0.06
# 1       10.34 1.66    Male     No  Sun  Dinner     3     0.16
# 2       21.01 3.50    Male     No  Sun  Dinner     3     0.17

# %%
def top(df, n = 5, column = "tip_pct"):
    return df.sort_values(by = column, ascending = False)[:n]

top(tips, n = 4)
# Out:
#      total_bill  tip     sex smoker  day    time  size  tip_pct
# 172        7.25 5.15    Male    Yes  Sun  Dinner     2     0.71
# 178        9.60 4.00  Female    Yes  Sun  Dinner     2     0.42
# 67         3.07 1.00  Female    Yes  Sat  Dinner     1     0.33
# 232       11.61 3.39    Male     No  Sat  Dinner     2     0.29

# %%
# DataFrame Groupby ojbect에 적용
tips.groupby("time", observed=False).apply(top)
# Out:
#             total_bill  tip     sex smoker   day    time  size  tip_pct
# time
# Lunch  149        7.51 2.00    Male     No  Thur   Lunch     2     0.27
#        221       13.42 3.48  Female    Yes   Fri   Lunch     2     0.26
#        194       16.58 4.00    Male    Yes  Thur   Lunch     2     0.24
# ...                ...  ...     ...    ...   ...     ...   ...      ...
# Dinner 67         3.07 1.00  Female    Yes   Sat  Dinner     1     0.33
#        232       11.61 3.39    Male     No   Sat  Dinner     2     0.29
#        183       23.17 6.50    Male    Yes   Sun  Dinner     4     0.28
#
# [10 rows x 8 columns]

# %%
tips.groupby(["time", "day"], observed=False).apply(top, n=1, column="total_bill")
# Out:
#                  total_bill   tip     sex smoker   day    time  size  tip_pct
# time   day
# Lunch  Thur 197       43.11  5.00  Female    Yes  Thur   Lunch     4     0.12
#        Fri  225       16.27  2.50  Female    Yes   Fri   Lunch     2     0.15
# Dinner Thur 243       18.78  3.00  Female     No  Thur  Dinner     2     0.16
#        Fri  95        40.17  4.73    Male    Yes   Fri  Dinner     4     0.12
#        Sat  170       50.81 10.00    Male    Yes   Sat  Dinner     3     0.20
#        Sun  156       48.17  5.00    Male     No   Sun  Dinner     6     0.10

# %%
def apply_mean(df):
    return df.mean()

tips.groupby("time", observed=False)[["total_bill", "tip"]].apply(apply_mean)  # .apply("mean")과 동일
# Out:
#         total_bill  tip
# time
# Lunch        17.17 2.73
# Dinner       20.80 3.10

# %%
def my_format(x):
    return f"{x:.1f}"

tips_num = tips.select_dtypes("number")

# element-wise, DataFrame method
tips_num.applymap(my_format)
# Out:
#     total_bill  tip size tip_pct
# 0         17.0  1.0  2.0     0.1
# 1         10.3  1.7  3.0     0.2
# 2         21.0  3.5  3.0     0.2
# ..         ...  ...  ...     ...
# 241       22.7  2.0  2.0     0.1
# 242       17.8  1.8  2.0     0.1
# 243       18.8  3.0  2.0     0.2
#
# [244 rows x 4 columns]

# %%
def peak_to_peak(arr):
    return arr.max() - arr.min()

# %%
tips_num
# Out:
#      total_bill  tip  size  tip_pct
# 0         16.99 1.01     2     0.06
# 1         10.34 1.66     3     0.16
# 2         21.01 3.50     3     0.17
# ..          ...  ...   ...      ...
# 241       22.67 2.00     2     0.09
# 242       17.82 1.75     2     0.10
# 243       18.78 3.00     2     0.16
#
# [244 rows x 4 columns]

# %%
# column-wise operation 열에서 가장 큰 값 - 작은 값
tips_num.apply(peak_to_peak)
# Out:
# total_bill   47.74
# tip           9.00
# size          5.00
# tip_pct       0.67
# dtype: float64

# %%
# row-wise operation 행에서 가장 큰 값 - 작은 값
tips_num.apply(peak_to_peak, axis="columns")
# Out:
# 0     16.93
# 1     10.18
# 2     20.84
#        ...
# 241   22.58
# 242   17.72
# 243   18.62
# Length: 244, dtype: float64

# %%
def f2(x):
    return pd.Series([x.min(), x.max()], index=["min", "max"])  # Series를 반환

# apply에 패스되는 함수가 Series를 반환하는 경우
tips_num.apply(f2)
# Out:
#      total_bill   tip  size  tip_pct
# min        3.07  1.00     1     0.04
# max       50.81 10.00     6     0.71

# %%
# Series Groupby object의 경우
tips.groupby("time", observed=False)["tip"].apply(f2)
# Out:
# time
# Lunch   min    1.25
#         max    6.70
# Dinner  min    1.00
#         max   10.00
# Name: tip, dtype: float64

# %%
# DataFrame GroupBy object의 경우
def f3(g):
    x = g["tip"]
    return pd.Series([x.min(), x.max()], index=["min", "max"])

tips.groupby("time", observed=False).apply(f3)
# Out:
#         min   max
# time
# Lunch  1.25  6.70
# Dinner 1.00 10.00

# %% [markdown]
# # merge(): Key에 해당하는 변수들의 값이 매치되는 방식으로 두 DataFrame이 combine

# %% [markdown]
# ## Primary Key인지 우선 확인

# %%
planes.duplicated(subset="tailnum").sum()

# (planes.value_counts("tailnum") > 1).sum()와 같음
# Out:
# 0

# %%
weather.duplicated(subset=["year", "month", "day", "hour", "origin"]).sum()
# Out:
# 3

# %%
(
    weather[["year", "month", "day", "hour", "origin"]]
    .value_counts()
    .reset_index(name="n")
    .query("n > 1")
)
#  year, month, day, hour, origin의 조합은 primary key 안 됨.
# Out:
#    year  month  day  hour origin  n
# 0  2013     11    3     1    EWR  2
# 1  2013     11    3     1    JFK  2
# 2  2013     11    3     1    LGA  2

# %%
# 다음과 같이 불명확한 정보를 처리한 후 사용
weather[
    weather.duplicated(
        subset=["year", "month", "day", "hour", "origin"], keep=False
    )  # keep=False: 중복된 모든 행을 True로 표시
]
# Out:
#       origin  year  month  day  hour  temp  dewp  humid  wind_dir  wind_speed  \
# 7318     EWR  2013     11    3     1 51.98 39.02  61.15    310.00        6.90
# 7319     EWR  2013     11    3     1 50.00 39.02  65.80    290.00        5.75
# 16023    JFK  2013     11    3     1 53.96 37.94  54.51    320.00        9.21
# 16024    JFK  2013     11    3     1 51.98 37.94  58.62    310.00        6.90
# 24729    LGA  2013     11    3     1 55.04 39.02  54.67    330.00        9.21
# 24730    LGA  2013     11    3     1 53.96 39.92  58.89    310.00        8.06
#
#        wind_gust  precip  pressure  visib                 time_hour
# 7318         NaN    0.00   1009.80  10.00 2013-11-03 01:00:00-04:00
# 7319         NaN    0.00   1010.50  10.00 2013-11-03 01:00:00-05:00
# 16023        NaN    0.00   1009.80  10.00 2013-11-03 01:00:00-04:00
# 16024        NaN    0.00   1010.50  10.00 2013-11-03 01:00:00-05:00
# 24729        NaN    0.00   1009.30  10.00 2013-11-03 01:00:00-04:00
# 24730        NaN    0.00   1010.20  10.00 2013-11-03 01:00:00-05:00

# %%
df_x = pd.DataFrame({"key": [1, 2, 3], "val_x": ["x1", "x2", "x3"]})
df_y = pd.DataFrame({"key": [1, 2, 4], "val_y": ["y1", "y2", "y3"]})
# Out:
#    key val_x val_y
# 0    1    x1    y1
# 1    2    x2    y2

# %%
df_x
# Out:
#    key val_x
# 0    1    x1
# 1    2    x2
# 2    3    x3

# %%
df_y
# Out:
#    key val_y
# 0    1    y1
# 1    2    y2
# 2    4    y3

# %%
pd.merge(df_x, df_y, on="key")  # 공통의 column이 있을 시 "on=" 생략 가능
# df_x.merge(df_y, on="key")와 동일
# Out:
#    key val_x val_y
# 0    1    x1    y1
# 1    2    x2    y2

# %%
pd.merge(df_x, df_y, how="left")
# Out:
#    key val_x val_y
# 0    1    x1    y1
# 1    2    x2    y2
# 2    3    x3   NaN

# %%
pd.merge(df_x, df_y, how="right")

# %%
pd.merge(df_x, df_y, how="outer")

# %%
flights2 = flights[
    ["year", "month", "day", "hour", "origin", "dest", "tailnum", "carrier"]
]

# flights에 항공사의 full name을 추가하고자 할때,
(
    flights2
    .merge(airlines, on="carrier", how="left")
)
# Out:
#         year  month  day  hour origin dest tailnum carrier  \
# 0       2013      1    1     5    EWR  IAH  N14228      UA
# 1       2013      1    1     5    LGA  IAH  N24211      UA
# 2       2013      1    1     5    JFK  MIA  N619AA      AA
# ...      ...    ...  ...   ...    ...  ...     ...     ...
# 336773  2013      9   30    12    LGA  BNA  N535MQ      MQ
# 336774  2013      9   30    11    LGA  CLE  N511MQ      MQ
# 336775  2013      9   30     8    LGA  RDU  N839MQ      MQ
#
#                           name
# 0        United Air Lines Inc.
# 1        United Air Lines Inc.
# 2       American Airlines Inc.
# ...                        ...
# 336773               Envoy Air
# 336774               Envoy Air
# 336775               Envoy Air
#
# [336776 rows x 9 columns]

# %%
flights2.merge(weather, how="left").head(3)  # on=["year", "month", "day", "hour", "origin"]
# Out:
#    year  month  day  hour origin dest tailnum carrier  temp  dewp  humid  \
# 0  2013      1    1     5    EWR  IAH  N14228      UA 39.02 28.04  64.43
# 1  2013      1    1     5    LGA  IAH  N24211      UA 39.92 24.98  54.81
# 2  2013      1    1     5    JFK  MIA  N619AA      AA 39.02 26.96  61.63
#
#    wind_dir  wind_speed  wind_gust  precip  pressure  visib  \
# 0    260.00       12.66        NaN    0.00   1011.90  10.00
# 1    250.00       14.96      21.86    0.00   1011.40  10.00
# 2    260.00       14.96        NaN    0.00   1012.10  10.00
#
#                   time_hour
# 0 2013-01-01 05:00:00-05:00
# 1 2013-01-01 05:00:00-05:00
# 2 2013-01-01 05:00:00-05:00

# %%
# year_x, year_y로 구분되어 표시
flights2.merge(planes, on="tailnum", how="left").head(3)
# Out:
#    year_x  month  day  hour origin dest tailnum carrier  year_y  \
# 0    2013      1    1     5    EWR  IAH  N14228      UA 1999.00
# 1    2013      1    1     5    LGA  IAH  N24211      UA 1998.00
# 2    2013      1    1     5    JFK  MIA  N619AA      AA 1990.00
#
#                       type manufacturer    model  engines  seats  speed  \
# 0  Fixed wing multi engine       BOEING  737-824     2.00 149.00    NaN
# 1  Fixed wing multi engine       BOEING  737-824     2.00 149.00    NaN
# 2  Fixed wing multi engine       BOEING  757-223     2.00 178.00    NaN
#
#       engine
# 0  Turbo-fan
# 1  Turbo-fan
# 2  Turbo-fan

# %%
# airports 데이터프레임에서 공항이름이 faa라는 이름의 column으로 존재.
# 도착지(dest)의 공항정보를 얻으려면, faa와 dest를 매치시키고,

flights2.merge(airports, left_on="dest", right_on="faa", how="left").head(5)
# Out:
#    year  month  day  hour origin dest tailnum carrier  faa  \
# 0  2013      1    1     5    EWR  IAH  N14228      UA  IAH
# 1  2013      1    1     5    LGA  IAH  N24211      UA  IAH
# 2  2013      1    1     5    JFK  MIA  N619AA      AA  MIA
# 3  2013      1    1     5    JFK  BQN  N804JB      B6  NaN
# 4  2013      1    1     6    LGA  ATL  N668DN      DL  ATL
#
#                               name   lat    lon     alt    tz  dst  \
# 0     George Bush Intercontinental 29.98 -95.34   97.00 -6.00    A
# 1     George Bush Intercontinental 29.98 -95.34   97.00 -6.00    A
# 2                       Miami Intl 25.79 -80.29    8.00 -5.00    A
# 3                              NaN   NaN    NaN     NaN   NaN  NaN
# 4  Hartsfield Jackson Atlanta Intl 33.64 -84.43 1026.00 -5.00    A
#
#               tzone
# 0   America/Chicago
# 1   America/Chicago
# 2  America/New_York
# 3               NaN
# 4  America/New_York

# %%
# airports 데이터프레임에서 공항이름이 faa라는 이름의 column으로 존재.
# 출발지(origin)의 공항정보를 얻으려면, faa와 origin를 매치시켜야 함.
flights2.merge(airports, left_on="origin", right_on="faa", how="left").head(5)
# Out:
#    year  month  day  hour origin dest tailnum carrier  faa  \
# 0  2013      1    1     5    EWR  IAH  N14228      UA  EWR
# 1  2013      1    1     5    LGA  IAH  N24211      UA  LGA
# 2  2013      1    1     5    JFK  MIA  N619AA      AA  JFK
# 3  2013      1    1     5    JFK  BQN  N804JB      B6  JFK
# 4  2013      1    1     6    LGA  ATL  N668DN      DL  LGA
#
#                   name   lat    lon  alt  tz dst             tzone
# 0  Newark Liberty Intl 40.69 -74.17   18  -5   A  America/New_York
# 1           La Guardia 40.78 -73.87   22  -5   A  America/New_York
# 2  John F Kennedy Intl 40.64 -73.78   13  -5   A  America/New_York
# 3  John F Kennedy Intl 40.64 -73.78   13  -5   A  America/New_York
# 4           La Guardia 40.78 -73.87   22  -5   A  America/New_York

# %%
top_dest = flights2['dest'].value_counts().head(10).reset_index(name = 'n')
top_dest
# Out:
#    dest      n
# 0   ORD  17283
# 1   ATL  17215
# 2   LAX  16174
# ..  ...    ...
# 7   FLL  12055
# 8   MIA  11728
# 9   DCA   9705
#
# [10 rows x 2 columns]

# %%
flights2.merge(top_dest, on="dest")  # inner join
# Out:
#         year  month  day  hour origin dest tailnum carrier      n
# 0       2013      1    1     5    JFK  MIA  N619AA      AA  11728
# 1       2013      1    1     6    EWR  MIA  N633AA      AA  11728
# 2       2013      1    1     6    EWR  MIA  N53442      UA  11728
# ...      ...    ...  ...   ...    ...  ...     ...     ...    ...
# 141142  2013      9   30    21    EWR  DCA  N14902      EV   9705
# 141143  2013      9   30    21    JFK  DCA  N807MQ      MQ   9705
# 141144  2013      9   30    14    JFK  DCA     NaN      9E   9705
#
# [141145 rows x 9 columns]

# %% [markdown]
# # concat(): 공통의 행 또는 열이 align되어 join
# # default: axis = 0

# %%
df1 = pd.DataFrame(
    np.arange(6).reshape(3, 2), index=["a", "b", "c"], columns=["one", "two"]
)
df2 = pd.DataFrame(
    5 + np.arange(4).reshape(2, 2), index=["a", "c"], columns=["three", "four"]
)

# %%
pd.concat([df1, df2])  # default: axis=0
# Out:
#    one  two  three  four
# a 0.00 1.00    NaN   NaN
# b 2.00 3.00    NaN   NaN
# c 4.00 5.00    NaN   NaN
# a  NaN  NaN   5.00  6.00
# c  NaN  NaN   7.00  8.00

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    one  two  three  four
# a    0    1   5.00  6.00
# b    2    3    NaN   NaN
# c    4    5   7.00  8.00

# %% [markdown]
# # melt(): Long Form 만들기

# %%
table4a_long = table4a.melt(
    id_vars="country",            # 고정할 컬럼
    value_vars=["1999", "2000"],  # value로 사용할 컬럼
    var_name="year",              # 컬럼에 있는 정보에 대한 변수명
    value_name="cases"            # value에 있는 정보에 대한 변수명
)

table4a_long
# Out:
#        country  year   cases
# 0  Afghanistan  1999     745
# 1       Brazil  1999   37737
# 2        China  1999  212258
# 3  Afghanistan  2000    2666
# 4       Brazil  2000   80488
# 5        China  2000  213766

# %%
# 생략시 모든 컬럼을 value_vars로 사용.
# 컬럼 이름은 각각 variable, value로 나타남
table4a_long = table4a.melt(id_vars="country")  # 또는 pd.melt() 이용
table4a_long
# Out:
#        country variable   value
# 0  Afghanistan     1999     745
# 1       Brazil     1999   37737
# 2        China     1999  212258
# 3  Afghanistan     2000    2666
# 4       Brazil     2000   80488
# 5        China     2000  213766

# %%
table4b_long = table4b.melt(
    id_vars="country",           # 고정할 컬럼
    value_vars=["1999", "2000"],  # value로 사용할 컬럼
    var_name="year",             # 컬럼에 있는 정보에 대한 변수명
    value_name="population",     # value에 있는 정보에 대한 변수명
)
table4b_long
# Out:
#        country  year  population
# 0  Afghanistan  1999    19987071
# 1       Brazil  1999   172006362
# 2        China  1999  1272915272
# 3  Afghanistan  2000    20595360
# 4       Brazil  2000   174504898
# 5        China  2000  1280428583

# %%
pd.merge(table4a_long, table4b_long)  # keys: "country" & "year"
# Out:
#         country variable   value  year  population
# 0   Afghanistan     1999     745  1999    19987071
# 1   Afghanistan     1999     745  2000    20595360
# 2   Afghanistan     2000    2666  1999    19987071
# ..          ...      ...     ...   ...         ...
# 9         China     1999  212258  2000  1280428583
# 10        China     2000  213766  1999  1272915272
# 11        China     2000  213766  2000  1280428583
#
# [12 rows x 5 columns]

# %% [markdown]
# # stack(): Long Form 만들기 2

# %%
table4a.set_index("country").stack()  # Series
# Out:
# country
# Afghanistan  1999       745
#              2000      2666
# Brazil       1999     37737
#              2000     80488
# China        1999    212258
#              2000    213766
# dtype: int64

# %%
table4a.set_index("country").stack().unstack(level=0)
# Out:
# country  Afghanistan  Brazil   China
# 1999             745   37737  212258
# 2000            2666   80488  213766

# %% [markdown]
# # pivot(): wide Format

# %%
table2.pivot(
    index=["country", "year"],  # index로 고정할 컬럼
    columns="type",             # 컬럼 이름으로 들어갈 컬럼
    values="count"              # 값로 들어갈 컬럼
)
# Out:
# type               cases  population
# country     year
# Afghanistan 1999     745    19987071
#             2000    2666    20595360
# Brazil      1999   37737   172006362
#             2000   80488   174504898
# China       1999  212258  1272915272
#             2000  213766  1280428583

# %%
# table1을 년도별로 wide form으로 변환하면?
table1.pivot(index="country", columns="year", values=["cases", "population"])  # values: list로 입력
# Out:
#               cases          population
# year           1999    2000        1999        2000
# country
# Afghanistan     745    2666    19987071    20595360
# Brazil        37737   80488   172006362   174504898
# China        212258  213766  1272915272  1280428583

# %% [markdown]
# # unstack(): wide Format 2

# %%
# unstack()은 index를 이용해 wide form으로 변환시켜 줌
# 맨 안쪽 index level (level=2)에 default로 적용

table2.set_index(["country", "year", "type"]).unstack()
# Out:
#                    count
# type               cases  population
# country     year
# Afghanistan 1999     745    19987071
#             2000    2666    20595360
# Brazil      1999   37737   172006362
#             2000   80488   174504898
# China       1999  212258  1272915272
#             2000  213766  1280428583

# %%
# able1을 년도별로 wide form으로 변환하면?
table1.set_index(["country", "year"]).unstack("year")
# Out:
#               cases          population
# year           1999    2000        1999        2000
# country
# Afghanistan     745    2666    19987071    20595360
# Brazil        37737   80488   172006362   174504898
# China        212258  213766  1272915272  1280428583

# %% [markdown]
# # str 활용해서 분리 및 통합

# %%
table3
# Out:
#        country  year               rate
# 0  Afghanistan  1999       745/19987071
# 1  Afghanistan  2000      2666/20595360
# 2       Brazil  1999    37737/172006362
# 3       Brazil  2000    80488/174504898
# 4        China  1999  212258/1272915272
# 5        China  2000  213766/1280428583

# %%
table3["rate"].str.split("/", expand=True)  # expand: list의 성분을 분리하여 컬럼으로 만듦
# Out:
#         0           1
# 0     745    19987071
# 1    2666    20595360
# 2   37737   172006362
# 3   80488   174504898
# 4  212258  1272915272
# 5  213766  1280428583

# %%
table3[["cases", "population"]] = table3.pop("rate").str.split("/", expand=True)  # pop: 제거와 선택 동시
table3
# Out:
#        country  year   cases  population
# 0  Afghanistan  1999     745    19987071
# 1  Afghanistan  2000    2666    20595360
# 2       Brazil  1999   37737   172006362
# 3       Brazil  2000   80488   174504898
# 4        China  1999  212258  1272915272
# 5        China  2000  213766  1280428583

# %%
# year를 앞 두자리와 뒤 두자리를 나누고자 하면 (seperate)
table3["year"].astype("string").str.extract(r'(\d{2})(\d{2})')
# Out:
#     0   1
# 0  19  99
# 1  20  00
# 2  19  99
# 3  20  00
# 4  19  99
# 5  20  00

# %%
table3[["century", "year"]] = table3.pop("year").astype("string").str.extract(r'(\d{2})(\d{2})')
table3
# Out:
#        country   cases  population century year
# 0  Afghanistan     745    19987071      19   99
# 1  Afghanistan    2666    20595360      20   00
# 2       Brazil   37737   172006362      19   99
# 3       Brazil   80488   174504898      20   00
# 4        China  212258  1272915272      19   99
# 5        China  213766  1280428583      20   00

# %%
# 다시 century와 year 합치기
table3["year_4d"] = table3["century"].str.cat(table3["year"])
table3
# Out:
#        country   cases  population century year year_4d
# 0  Afghanistan     745    19987071      19   99    1999
# 1  Afghanistan    2666    20595360      20   00    2000
# 2       Brazil   37737   172006362      19   99    1999
# 3       Brazil   80488   174504898      20   00    2000
# 4        China  212258  1272915272      19   99    1999
# 5        China  213766  1280428583      20   00    2000

# %% [markdown]
# # pd.crosstab(): 두 카테고리 변수의 모든 level 쌍에 대한 count.
# ## normalize: 비율을 계산
# ## margins: 행과 열로 합

# %%
pd.crosstab(tips["day"], tips["time"])

# groupby를 이용 - tips.groupby(["day", "time"], observed=False).size()  # observed: categorical type의 변수에 대한 처리 (default: True)
# # groupby & unstack를 이용 - tips.groupby(["day", "time"], observed=False).size().unstack()
# Out:
# time  Lunch  Dinner
# day
# Thur     61       1
# Fri       7      12
# Sat       0      87
# Sun       0      76

# %%
pd.crosstab(tips["day"], tips["time"], margins=True)
# Out:
# time  Lunch  Dinner  All
# day
# Thur     61       1   62
# Fri       7      12   19
# Sat       0      87   87
# Sun       0      76   76
# All      68     176  244

# %%
pd.crosstab(tips["day"], tips["time"], normalize='all', margins=True)
# Out:
# time  Lunch  Dinner  All
# day
# Thur   0.25    0.00 0.25
# Fri    0.03    0.05 0.08
# Sat    0.00    0.36 0.36
# Sun    0.00    0.31 0.31
# All    0.28    0.72 1.00

# %%
pd.crosstab(tips["day"], tips["time"], normalize='columns')
# Out:
# time  Lunch  Dinner
# day
# Thur   0.90    0.01
# Fri    0.10    0.07
# Sat    0.00    0.49
# Sun    0.00    0.43

# %% [markdown]
# # pivot_table():
# ## count 대신 mean
# ## mean 외에 다른 aggregation 함수를 지정할 수 있음
# ## grouping을 할 변수들을 (index and/or columns)과 aggregate할 변수 지정 (values)

# %%
# grouping을 할 변수들을 index에 지정, aggregate할 변수 지정
tips.pivot_table(index=["day", "time"], values="tip")  # dropna=True

# # groupby를 이용
# tips.groupby(["day", "time"], observed=True)["tip"].mean()
# Out:
#              tip
# day  time
# Thur Lunch  2.77
#      Dinner 3.00
# Fri  Lunch  2.38
#      Dinner 2.94
# Sat  Dinner 2.99
# Sun  Dinner 3.26

# %%
# grouping을 할 변수들을 index & columns에 지정, aggregate할 변수 지정
tips.pivot_table(index="day", columns="time", values="tip")
# Out:
# time  Lunch  Dinner
# day
# Thur   2.77    3.00
# Fri    2.38    2.94
# Sat     NaN    2.99
# Sun     NaN    3.26

# %%
# 두 개 이상의 변수에 대한 aggregation
tips.pivot_table(index="day", columns="time", values=["tip", "total_bill"])

# groupby를 이용
# tips.groupby(["day", "time"])[["tip", "total_bill"]].mean().unstack()  # observed=True
# Out:
#        tip        total_bill
# time Lunch Dinner      Lunch Dinner
# day
# Thur  2.77   3.00      17.66  18.78
# Fri   2.38   2.94      12.85  19.66
# Sat    NaN   2.99        NaN  20.44
# Sun    NaN   3.26        NaN  21.41

# %%
# margins 추가
tips.pivot_table(index="day", columns="time", values="tip", margins=True)
# Out:
# time  Lunch  Dinner  All
# day
# Thur   2.77    3.00 2.77
# Fri    2.38    2.94 2.73
# Sat     NaN    2.99 2.99
# Sun     NaN    3.26 3.26
# All    2.73    3.10 3.00
